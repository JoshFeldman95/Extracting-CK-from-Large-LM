# %%
from experiments import DirectTemplate, EnumeratedTemplate, KnowledgeMiner, PredefinedTemplate
from pytorch_pretrained_bert import BertForMaskedLM, GPT2LMHeadModel

# %%
bert = BertForMaskedLM.from_pretrained('bert-large-uncased')

# %%
ck_miner = KnowledgeMiner(
    './NovelTuples.csv', 
    'cpu', 
    PredefinedTemplate, 
    bert,
    template_loc = './relation_map.json'
)

# %%
df = ck_miner.make_predictions()
# Out:
# 0 (12.270675659179688, 0.3685569763183594, 11, '[CLS] something you might do while sit is take notice . [SEP]')
# 1 (9.598297119140625, 2.01908540725708, 9, '[CLS] something you might do while soil moisture is temperature . [SEP]')
# 2 (14.504677772521973, 0.8825278282165527, 19, '[CLS] something you might do while increase is population growth . [SEP]')
# 3 (12.308077812194824, 2.3170580863952637, 10, '[CLS] something you might do while term is art history . [SEP]')
# 4 (8.689223289489746, 2.316406726837158, 16, '[CLS] something you might do while gold is silver mining . [SEP]')
# 5 (11.050251960754395, -0.4513678550720215, 19, '[CLS] something you might do while air is noise pollution . [SEP]')
# 6 (7.913027763366699, 1.526829719543457, 9, '[CLS] something you might do while roller hockey is ice . [SEP]')
# 7 (7.070811748504639, 2.3837640285491943, 7, '[CLS] something you might do while play is hockey league . [SEP]')
# ...
