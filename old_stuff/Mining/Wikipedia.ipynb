# %%
import pandas as pd
import numpy as np
import re
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import calinski_harabaz_score
from sklearn.preprocessing import StandardScaler

# %%
df_results_LM = pd.read_csv('../FilesToUploadToColab/wikipedia_predictions_LM.csv')
df_results_concat = pd.read_csv('../FilesToUploadToColab/wikipedia_predictions_concat.csv')
df_tuples = pd.read_csv('../FilesToUploadToColab/NovelTuples.csv', sep = '\t', header = None)
df_tuples.columns = ('rel','head','tail','misc','misc2')

# %%
def score(tail_cond, tail_marg, head_cond, head_marg, lam = 1):
    return ((lam * (tail_cond + head_cond) - (tail_marg + head_marg)))/2
    # return lam * tail_cond + (k - 1) * head_marg - tail_marg

# %%
best_lams = []
for df in [df_results_LM, df_results_concat]:  
    sils = []
    lams = []
    for lam in np.arange(1, 10, 0.05):
        ss = StandardScaler()
        df_tuples['temp'] = score(
            df.tail_conditional,
            df.tail_marginal, 
            df.head_conditional, 
            df.head_marginal, 
            lam = lam
        )
        gm = GaussianMixture(5).fit(df_tuples[['temp']])
        dat = ss.fit_transform(df_tuples[['temp']])
        pred = gm.fit_predict(dat)
        sil = gm.aic(dat)
        sils.append(sil)
        lams.append(lam)
        #accs.append(acc)
    sils = np.array(sils)
    #accs = np.array(accs)
    best_lam = lams[sils.argmax()]
    best_lams.append(best_lam)

# %%
best_lams
# Out:
# [1.4500000000000004, 1.4000000000000004]

# %%
best_lams = []
for df in [df_results_LM, df_results_concat]:  
    sils = []
    lams = []
    for lam in np.arange(1, 10, 0.05):
        df_tuples['temp'] = score(
            df.tail_conditional,
            df.tail_marginal, 
            df.head_conditional, 
            df.head_marginal, 
            lam = lam
        )
        gm = GaussianMixture(5).fit(df_tuples[['temp']])
        sil = calinski_harabaz_score(df_tuples[['temp']], gm.predict(df_tuples[['temp']]))
        #acc = np.mean((gm.cluster_centers_.argmax() == df.label) == gm.predict(df_tuples[['score']]))
        sils.append(sil)
        lams.append(lam)
        #accs.append(acc)
    sils = np.array(sils)
    #accs = np.array(accs)
    best_lam = lams[sils.argmax()]
    best_lams.append(best_lam)

# %%
for lam in np.arange(1, 11, 1):
    df_tuples[f'score_LM_{lam}'] = score(
        df_results_LM.tail_conditional,
        df_results_LM.tail_marginal, 
        df_results_LM.head_conditional, 
        df_results_LM.head_marginal, 
        lam = lam
    )
    df_tuples[f'score_concat_{lam}'] = score(
        df_results_concat.tail_conditional,
        df_results_concat.tail_marginal, 
        df_results_concat.head_conditional, 
        df_results_concat.head_marginal, 
        lam = lam
    )

# %%
df_tuples['sent_LM'] = df_results_LM['sent']
df_tuples['sent_concat'] = df_results_concat['sent']

# %%
df_tuples['score_LM_cluster'] = score(
    df.tail_conditional,
    df.tail_marginal, 
    df.head_conditional, 
    df.head_marginal, 
    lam = best_lams[0]
)
df_tuples['score_concat_cluster'] = score(
    df.tail_conditional,
    df.tail_marginal, 
    df.head_conditional, 
    df.head_marginal, 
    lam = best_lams[1]
)

# %%
df_tuples['top_100'] = False

# %%
for clm in df_tuples.columns:
    if 'score' in clm:
        df_tuples[clm.replace('score', 'rank')] = df_tuples[clm].rank(ascending=False)

# %%
rank_clms = [clm for clm in df_tuples.columns if re.match('rank_LM_[0-9]', clm)]
df_tuples['score_LM_ensemble'] = - df_tuples[rank_clms].mean(axis = 1)

rank_clms = [clm for clm in df_tuples.columns if re.match('rank_concat_[0-9]', clm)]
df_tuples['score_concat_ensemble'] = - df_tuples[rank_clms].mean(axis = 1)

# %%
for clm in df_tuples.columns:
    if 'score' in clm:
        df_tuples.loc[df_tuples[clm].rank(ascending=False) <= 100, 'top_100'] = True

# %%
for clm in df_tuples.columns:
    if 'score' in clm:
        df_tuples[clm.replace('score', 'rank')] = df_tuples[clm].rank(ascending=False)

# %%
df_tuples[df_tuples.top_100]
# Out:
#               rel                       head                        tail  \
# 8     HasSubevent                 wind power                      energy
# 13    HasSubevent                   dopamine  norepinephrine transporter
# 26    HasSubevent                 beta decay                    emission
# 50    HasSubevent                 set theory                       logic
# 51    HasSubevent             köppen climate                         cwa
# 58    HasSubevent                    airport                    air base
# 66    HasSubevent                     signal                 phase shift
# 84    HasSubevent              mating system                    polygyny
# 94    HasSubevent             reconnaissance               ground attack
# 104   HasSubevent             trade deadline                  draft pick
# 121   HasSubevent                    emitter               input voltage
# 146   HasSubevent                       team                  head coach
# 154   HasSubevent                  architect          landscape designer
# 167   HasSubevent                  headphone                 card reader
# 173   HasSubevent           operating system                      server
# 246   HasSubevent                      pilot              control column
# 264   HasSubevent                   producer            studio executive
# 285   HasSubevent       coalition government                     cabinet
# 300    AtLocation             stock exchange                      market
# 310    AtLocation         hockey association             national hockey
# 318    AtLocation                    village                northern end
# 322    AtLocation              bass clarinet                    trombone
# 324    AtLocation                       book               public domain
# 326    AtLocation                      coach               national team
# 361    AtLocation                    theorem                        of a
# 365    AtLocation                      novel                   book form
# 374    AtLocation           dual carriageway          single carriageway
# 375    AtLocation               homomorphism            orthogonal group
# 380    AtLocation  electromagnetic radiation    electromagnetic spectrum
# 411    AtLocation             award for best                presentation
# ...           ...                        ...                         ...
# 2704       Causes                        law              foreign policy
# 2713       Causes                       film              silent version
# 2722       Causes               urban design                architecture
# 2724       Causes          economic activity                  population
# 2725       Causes              skin friction                        drag
# 2728       Causes                        set               finite subset
# 2749       Causes                       simd          single instruction
# 2753       Causes         insulin resistance          metabolic syndrome
# 2766       Causes            political power                         war
# 2773       Causes                     policy             economic crisis
# 2775       Causes                       army              fighting force
# 2776       Causes                      brain                 spinal cord
# 2787       Causes             majority party          majority coalition
# 2790       Causes           neutron emission                     fission
# 2811       Causes                    playoff           championship game
# 2817       Causes            former football                       coach
# 2823       Causes                         ra                     sun god
# 2834       Causes                       book              printing press
# 2859       Causes                    episode               season finale
# 2865       Causes               municipality            local government
# 2885       Causes                   iron ore              steel industry
# 2894       Causes                     server                  session id
# 2911       Causes                    playoff                   wild card
# 2915       Causes               northern end                       north
# 2924       Causes       association football               popular sport
# 2928       Causes                agriculture                    land use
# 2935       Causes                 government                  land grant
# 2952       Causes             control system                      engine
# 2956       Causes                     runner                  first base
# 2983       Causes                county seat               state capital
#
#       misc     misc2        temp  score_LM_1  score_concat_1  score_LM_2  \
# 8       17  0.335372  -64.409269    3.671586        3.675419   -7.367223
# 13       7  0.220842 -192.816688    4.098280        7.844059  -26.461197
# 26      16  0.102018  -60.663568    4.156948        5.881988   -9.817300
# 50      31  0.044019  -36.489515    2.925434        7.268706   -7.026707
# 51       7  0.043962 -241.158432    6.957806       -2.736583   -8.504061
# 58      11  0.035322  -61.173613    3.476409       10.509255   -7.632346
# 66       7  0.021044  -67.582112    4.893082        8.604543   -5.099000
# 84       7  0.013174 -129.421728    5.310981        7.262086  -16.378161
# 94       8  0.010487  -95.391164    2.633332        8.234715   -9.380363
# 104      7  0.008709 -115.892033    5.041932       10.743823   -8.149487
# 121      8  0.006271  -92.997151    4.603841        7.291043  -11.424908
# 146    239  0.003625  -65.958621    4.899662        9.640532   -6.249980
# 154      7  0.002966  -95.163113    4.083040        7.055789   -5.246900
# 167     10  0.002356 -109.705621    1.430980        7.451281  -16.960206
# 173     37  0.002218  -72.610619    2.359856        6.501518  -11.670822
# 246     10  0.000190 -106.024738    1.574347        7.661928  -14.871172
# 264      7  0.000094 -108.029728    6.622714        5.630175   -1.635265
# 285     10  0.000017  -73.652594    4.276383        6.886583   -8.901621
# 300     20  0.993670  -68.567347    2.476737        6.117569   -3.805910
# 310      9  0.749859 -119.996684    9.683025        4.728859   -4.051245
# 318     15  0.576938  -99.143934    3.177124        1.117442   -1.912926
# 322      7  0.522364  -77.989566    4.871769        7.033336   -7.226577
# 324     29  0.475342  -71.767688    1.517930        3.371624   -2.664409
# 326     46  0.464173  -88.307382    6.341546        3.230151   -0.937919
# 361      8  0.231792  -56.735073   -0.415620        2.443240  -10.525553
# 365     23  0.218896  -89.973094    4.897285        1.380788   -1.202596
# 374     13  0.181428 -133.872189    9.824411        5.042912   -0.152197
# 375      7  0.179974 -144.295553   11.885588        2.618858    3.693551
# 380      8  0.170424  -80.780506    4.948683        7.605008   -2.030999
# 411     42  0.100644  -67.474332    3.023660        5.620256   -9.922713
# ...    ...       ...         ...         ...             ...         ...
# 2704     8  0.584193  -73.023987    6.748297        8.312762   -1.715486
# 2713     7  0.303346 -124.691783    6.745062        1.915642    1.620229
# 2722    11  0.138979  -60.014059    3.701662        6.591793   -6.491177
# 2724     8  0.132332  -65.174006    1.884309        3.021927   -5.309485
# 2725    11  0.125132  -60.619085    2.767467        2.767467   -4.314829
# 2728    12  0.114969  -65.007633    3.745953        8.350599   -7.187000
# 2749     9  0.064812 -110.914053    9.136376        7.696215   -1.932491
# 2753    10  0.059120  -37.065873    6.442260        6.442260    1.581016
# 2766     8  0.035024  -53.603810    3.297135        3.532493   -5.479724
# 2773     7  0.029795  -69.322018    3.682266        3.347415   -1.191738
# 2775    14  0.027933  -86.994230    5.637482        6.994636   -6.029922
# 2776   152  0.026268  -55.888476    3.216695        4.268272   -2.838640
# 2787     7  0.021573  -54.650439    8.061796       11.156294   -0.400723
# 2790     7  0.020641  -52.073429    4.654035        4.634531   -1.821821
# 2811    10  0.011765  -64.999791    7.532490       10.076185    0.250788
# 2817     8  0.010716 -106.415302    6.346059        6.346059   -6.252975
# 2823    10  0.009286  -75.586442    3.288078        6.835052   -6.017921
# 2834    12  0.006988 -100.710697    5.127250        7.405341   -6.574862
# 2859    12  0.003277  -67.621058    4.513090        7.706866   -0.776804
# 2865    60  0.002956  -65.034254    4.745918        7.175953   -1.715920
# 2885     7  0.001786  -84.679442    6.318713        7.095229   -0.468726
# 2894    10  0.001478  -91.007816    3.560460        8.111776   -7.177666
# 2911    12  0.001021  -55.949454    6.986088       13.309272   -0.491141
# 2915    12  0.000842  -79.889649    6.429585        6.429585   -3.215023
# 2924    15  0.000703 -105.070916    2.410665        9.835260   -7.673696
# 2928     7  0.000637  -45.709928    4.094147        4.094147   -1.470554
# 2935    12  0.000433  -68.719404    3.451506        6.543954   -4.107769
# 2952    13  0.000243  -78.793627    1.279545        7.024067   -8.467011
# 2956    38  0.000205  -68.447795    2.417516        7.299274   -7.196788
# 2983    10  0.000027  -96.456001    7.556851        8.081614    0.118044
#
#       score_concat_2  ...  rank_LM_9  rank_concat_9  rank_LM_10  \
# 8          -3.931808  ...     1318.0           78.0      1329.0
# 13        -14.576137  ...     2993.0         2956.0      2993.0
# 26         -1.553270  ...     2276.0           53.0      2283.0
# 50          2.379519  ...      984.0            4.0       994.0
# 51        -29.375896  ...     2511.0         2990.0      2523.0
# 58          2.499996  ...     1349.0           52.0      1364.0
# 66          0.092068  ...      915.0          109.0       933.0
# 84         -8.009849  ...     2958.0         2158.0      2961.0
# 94         -3.343596  ...     1734.0          712.0      1742.0
# 104        -3.405435  ...     2019.0         1582.0      2037.0
# 121        -3.914342  ...     2658.0          648.0      2674.0
# 146         1.193699  ...     1305.0           90.0      1319.0
# 154        -4.365318  ...      747.0          710.0       751.0
# 167        -5.638876  ...     2893.0         1318.0      2893.0
# 173        -2.337827  ...     2330.0          171.0      2338.0
# 246        -5.040493  ...     2764.0         1141.0      2768.0
# 264        -7.069255  ...      376.0         1233.0       380.0
# 285        -2.112208  ...     2044.0          183.0      2066.0
# 300        -2.227114  ...      159.0          122.0       155.0
# 310        -9.206956  ...     2008.0         1780.0      2047.0
# 318       -10.084947  ...       63.0          886.0        59.0
# 322        -2.466429  ...     1666.0          264.0      1684.0
# 324        -5.023829  ...       32.0          164.0        32.0
# 326        -6.997507  ...      221.0          514.0       223.0
# 361        -4.168862  ...     1171.0           41.0      1164.0
# 365        -8.826350  ...      109.0          580.0       111.0
# 374       -10.478329  ...      732.0         2323.0       755.0
# 375       -13.796160  ...      254.0         2596.0       269.0
# 380        -2.270469  ...      200.0          328.0       201.0
# 411        -2.546737  ...     2022.0          112.0      2029.0
# ...              ...  ...        ...            ...         ...
# 2704       -0.775143  ...      415.0          174.0       428.0
# 2713      -12.230439  ...       44.0         1996.0        44.0
# 2722       -0.850202  ...     1034.0           49.0      1046.0
# 2724       -4.597730  ...      287.0           91.0       285.0
# 2725       -4.314829  ...      257.0           55.0       257.0
# 2728        0.154148  ...     1284.0           80.0      1291.0
# 2749       -5.556329  ...     1091.0         1372.0      1125.0
# 2753        1.581016  ...       38.0            6.0        38.0
# 2766       -2.851451  ...      630.0           24.0       636.0
# 2773       -4.772075  ...       50.0          139.0        50.0
# 2775       -3.506913  ...     1456.0          465.0      1489.0
# 2776       -2.453152  ...      122.0           35.0       120.0
# 2787        3.803586  ...      378.0           27.0       393.0
# 2790       -1.701554  ...      148.0           17.0       150.0
# 2811        1.687808  ...      198.0           76.0       204.0
# 2817       -6.252975  ...     1764.0         1162.0      1795.0
# 2823       -2.374053  ...      759.0          212.0       765.0
# 2834       -4.674663  ...     1501.0          919.0      1521.0
# 2859       -0.709662  ...       65.0          110.0        64.0
# 2865       -0.892226  ...      145.0           82.0       147.0
# 2885       -3.158924  ...      164.0          406.0       172.0
# 2894       -2.963038  ...     1219.0          586.0      1238.0
# 2911        5.570867  ...      237.0           32.0       245.0
# 2915       -3.215023  ...      752.0          305.0       760.0
# 2924       -3.003419  ...     1051.0         1089.0      1057.0
# 2928       -1.470554  ...       79.0           11.0        78.0
# 2935       -1.865360  ...      321.0          125.0       319.0
# 2952       -2.564502  ...      985.0          281.0       987.0
# 2956       -1.164086  ...      893.0          117.0       899.0
# 2983       -3.598566  ...      222.0          755.0       229.0
#
#       rank_concat_10  rank_LM_cluster  rank_concat_cluster  score_LM_ensemble  \
# 8               77.0            224.0                239.0            -1125.8
# 13            2958.0           1832.0               1680.0            -2731.1
# 26              53.0             67.0                 72.0            -1903.6
# 50               5.0             11.0                 11.0             -906.4
# 51            2990.0           2991.0               2991.0            -1994.0
# 58              58.0              5.0                  5.0            -1163.5
# 66             114.0             23.0                 24.0             -733.0
# 84            2189.0            507.0                467.0            -2646.1
# 94             742.0            116.0                109.0            -1539.6
# 104           1634.0             80.0                 67.0            -1616.5
# 121            660.0            155.0                153.0            -2268.6
# 146             96.0             12.0                 12.0            -1036.0
# 154            731.0            187.0                180.0             -647.3
# 167           1351.0            257.0                242.0            -2712.0
# 173            173.0             97.0                 98.0            -2094.3
# 246           1178.0            207.0                197.0            -2564.6
# 264           1260.0            460.0                439.0             -277.6
# 285            190.0             79.0                 79.0            -1690.2
# 300            124.0             98.0                100.0             -257.7
# 310           1795.0            864.0                830.0            -1398.8
# 318            878.0           1303.0               1317.0             -133.6
# 322            274.0             94.0                 92.0            -1325.2
# 324            163.0            317.0                329.0             -186.1
# 326            511.0            563.0                565.0             -173.3
# 361             40.0            270.0                292.0            -1368.0
# 365            571.0           1011.0               1036.0             -121.6
# 374           2336.0           1107.0               1057.0             -458.3
# 375           2602.0           2030.0               1995.0             -141.6
# 380            342.0             74.0                 71.0             -193.0
# 411            112.0            120.0                126.0            -1759.5
# ...              ...              ...                  ...                ...
# 2704           179.0             37.0                 35.0             -302.0
# 2713          1997.0           1745.0               1726.0              -41.2
# 2722            49.0             54.0                 55.0             -892.5
# 2724            88.0            293.0                301.0             -407.7
# 2725            51.0            275.0                293.0             -324.1
# 2728            84.0             25.0                 26.0            -1085.5
# 2749          1407.0            244.0                234.0             -725.1
# 2753             6.0             14.0                 16.0              -39.0
# 2766            24.0            169.0                178.0             -592.3
# 2773           139.0            296.0                305.0             -104.6
# 2775           472.0            147.0                143.0            -1121.9
# 2776            35.0            139.0                147.0             -188.5
# 2787            29.0              4.0                  3.0             -256.5
# 2790            16.0             96.0                104.0             -158.9
# 2811            85.0              8.0                  8.0             -143.6
# 2817          1191.0            339.0                324.0            -1334.3
# 2823           226.0             91.0                 91.0             -705.0
# 2834           949.0            191.0                190.0            -1177.4
# 2859           115.0             42.0                 41.0              -94.0
# 2865            86.0             51.0                 51.0             -152.7
# 2885           416.0            128.0                124.0             -132.1
# 2894           608.0            101.0                 93.0            -1050.2
# 2911            38.0              1.0                  1.0             -175.0
# 2915           313.0            142.0                139.0             -554.6
# 2924          1128.0             73.0                 66.0             -997.0
# 2928            11.0             92.0                105.0             -118.7
# 2935           129.0             71.0                 73.0             -340.6
# 2952           290.0             99.0                 99.0            -1047.4
# 2956           122.0             57.0                 57.0             -867.3
# 2983           782.0            134.0                125.0             -157.1
#
#       score_concat_ensemble  rank_LM_ensemble  rank_concat_ensemble
# 8                    -156.2            1092.0                 108.0
# 13                  -2583.7            2805.0                2653.0
# 26                    -67.9            1925.0                  38.0
# 50                    -12.4             874.0                   3.0
# 51                  -2981.2            1997.0                2992.0
# 58                    -31.3            1129.0                  12.0
# 66                    -71.9             690.0                  44.0
# 84                  -1636.7            2721.0                1656.0
# 94                   -487.6            1538.0                 437.0
# 104                 -1022.9            1614.0                1009.0
# 121                  -462.0            2321.0                 407.0
# 146                   -54.4             998.0                  23.0
# 154                  -516.5             607.0                 454.5
# 167                  -938.0            2786.0                 905.5
# 173                  -143.6            2108.0                  98.0
# 246                  -804.8            2631.0                 761.0
# 264                  -974.4             234.0                 959.0
# 285                  -145.3            1681.0                  99.0
# 300                  -115.9             218.0                  80.0
# 310                 -1471.6            1380.0                1482.0
# 318                 -1054.8             103.0                1041.0
# 322                  -198.8            1295.0                 146.0
# 324                  -241.3             147.0                 179.0
# 326                  -542.6             137.0                 487.0
# 361                  -177.8            1347.0                 129.5
# 365                  -745.0              93.0                 691.0
# 374                 -1914.6             412.0                1944.0
# 375                 -2362.0             108.0                2408.0
# 380                  -228.6             155.0                 172.0
# 411                  -119.2            1770.0                  83.0
# ...                     ...               ...                   ...
# 2704                 -119.5             251.0                  85.0
# 2713                -1895.8              25.0                1922.0
# 2722                  -52.9             857.0                  22.0
# 2724                 -196.4             356.0                 145.0
# 2725                 -176.2             276.0                 126.0
# 2728                  -56.5            1050.0                  24.0
# 2749                 -971.0             681.0                 952.0
# 2753                  -19.9              22.0                   7.0
# 2766                 -106.0             541.0                  69.0
# 2773                 -218.9              76.0                 165.0
# 2775                 -344.6            1085.0                 280.5
# 2776                  -89.8             148.0                  58.0
# 2787                  -14.5             214.5                   4.5
# 2790                  -63.3             124.0                  32.0
# 2811                  -46.5             109.0                  19.0
# 2817                 -878.8            1307.0                 835.0
# 2823                 -167.9             660.5                 119.0
# 2834                 -654.4            1150.0                 586.0
# 2859                  -82.8              66.0                  54.0
# 2865                  -70.7             116.0                  42.0
# 2885                 -299.8             101.0                 233.0
# 2894                 -395.7            1020.0                 342.0
# 2911                  -14.8             138.0                   6.0
# 2915                 -241.9             504.0                 180.0
# 2924                 -702.3             956.0                 640.0
# 2928                  -68.9              90.0                  41.0
# 2935                 -109.8             292.0                  76.0
# 2952                 -210.9            1016.0                 158.0
# 2956                  -94.0             821.0                  62.0
# 2983                 -519.5             122.0                 459.0
#
# [306 rows x 57 columns]

# %%
df_tuples[df_tuples.top_100].to_csv(f'../FilesToUploadToColab/wikipedia_top.csv')
