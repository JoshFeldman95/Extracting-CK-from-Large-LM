# %%
import spacy
from pytorch_pretrained_bert import BertTokenizer, BertForMaskedLM
from torch import Tensor
import torch
import re
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased')
nouns = []
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

for token in tokenizer.vocab.keys():
    doc = nlp(token)
    if doc[0].pos_ == "NOUN":
        nouns.append(token)

# %%
bert = BertForMaskedLM.from_pretrained('bert-large-uncased')

# %%
emb = bert.bert.embeddings.word_embeddings.weight

# %%
emb = emb/emb.norm(dim = 1).reshape(-1,1)

# %%
_, similar_tokens_matrix = torch.mm(emb, emb.transpose(0,1)).topk(100)

# %%
df = pd.read_csv('../FilesToUploadToColab/test.txt', sep = '\t', header = None)
df.columns = ('rel', 'head','tail','label')

# %%
df.rel.value_counts()
# Out:
# AtLocation          479
# IsA                 396
# UsedFor             339
# CapableOf           280
# HasPrerequisite     226
# HasSubevent         170
# HasProperty         143
# HasA                98
# Causes              93
# PartOf              52
# MadeOf              28
# ReceivesAction      22
# NotCapableOf        20
# Desires             17
# MotivatedByGoal     15
# CausesDesire        6
# CreatedBy           5
# NotHasProperty      4
# RelatedTo           3
# DefinedAs           2
# NotIsA              1
# HasFirstSubevent    1
# Name: rel, dtype: int64

# %%
def good_word(orig_w, new_w):
    if "#" in new_w:
        return False
    if orig_w[:-1] in new_w:
        return False
    if not new_w.isalpha():
        return False
    return True
relations = [
    'AtLocation',
    'IsA',            
    'HasPrerequisite',     
    'HasA',
    'PartOf'
]

# %%
count = 0
with open('./candidate_BERT.txt', 'w') as f:
    for n in nouns[115:165]:
        token = tokenizer.convert_tokens_to_ids([n])[0]
        similar_tokens = similar_tokens_matrix[token]
        similar_words = tokenizer.convert_ids_to_tokens(similar_tokens.tolist())[:10]
        good_words = [w for w in similar_words if good_word(n, w)]
        print(n)
        print(good_words)
        for idx, gw in enumerate(good_words):
            if idx > 5:
                continue
            for r in relations:
                count += 2
                f.write('\t'.join((r, n, gw, '2'))+'\n')
                f.write('\t'.join((r, gw, n, '2'))+'\n')
# Out:
# time
# ['day', 'it', 'one', 'the', 'period']
# school
# ['college', 'university', 'house', 'church', 'work', 'education', 'academy', 'town']
# years
# ['months', 'decades', 'days', 'weeks', 'seasons', 'centuries', 'decade', 'hours']
# world
# ['international', 'life', 'city', 'global', 'country', 'universe', 'european', 'state']
# year
# ['month', 'season', 'week', 'day', 'decade', 'summer', 'months', 'time']
# city
# ['town', 'village', 'state', 'country', 'county', 'house', 'world', 'district']
# state
# ['city', 'government', 'national', 'county', 'country', 'world', 'public', 'the']
# people
# ['men', 'women', 'person', 'man', 'children', 'family', 'they']
# part
# ['portion', 'one', 'half', 'section', 'a', 'all', 'side']
# university
# ['college', 'school', 'institute', 'city', 'academy', 'campus', 'student', 'academic']
# don
# ['didn', 'wouldn', 'can', 'con', 'won', 'dan', 'haven']
# way
# ['far', 'time', 'path', 'means', 'place', 'road', 'manner']
# head
# ['face', 'body', 'back', 'house', 'hand', 'chief']
# team
# ['club', 'group', 'squad', 'side', 'company', 'crew', 'family', 'project']
# film
# ['movie', 'movies', 'video', 'cinema', 'television', 'book', 'documentary']
# work
# ['project', 'play', 'business', 'use', 'school']
# day
# ['night', 'year', 'morning', 'week', 'time', 'evening', 'afternoon']
# family
# ['group', 'house', 'people', 'mother', 'community', 'father', 'home', 'children']
# man
# ['men', 'people', 'boy', 'person', 'guy', 'girl', 'one']
# eyes
# ['gaze', 'face', 'hands', 'lips', 'mouth', 'ears', 'stare']
# house
# ['home', 'room', 'building', 'family', 'place', 'city', 'school']
# season
# ['year', 'campaign', 'month', 'summer', 'week', 'winter', 'years']
# war
# ['battle', 'conflict', 'military', 'army', 'wwii']
# states
# ['countries', 'says', 'kingdom', 'nations', 'asserts', 'provinces', 'cities']
# life
# ['lives', 'world', 'living', 'people', 'family', 'time', 'live', 'work']
# north
# ['south', 'west', 'east', 'southwest', 'western', 'southeast']
# name
# ['title', 'word', 'term', 'moniker', 'number']
# place
# ['position', 'spot', 'house', 'put', 'time', 'location', 'area']
# group
# ['band', 'team', 'family', 'company', 'class', 'area', 'series']
# area
# ['region', 'district', 'local', 'city', 'site', 'group', 'town', 'section']
# series
# ['show', 'group', 'program', 'set', 'production', 'season', 'project']
# home
# ['house', 'back', 'family', 'out', 'in', 'there', 'the']
# music
# ['song', 'art', 'sound', 'songs', 'singing', 'band', 'entertainment']
# hand
# ['arm', 'fingers', 'finger', 'head', 'palm', 'foot', 'face']
# number
# ['variety', 'amount', 'name', 'group', 'quantity', 'series']
# company
# ['group', 'corporation', 'firm', 'business', 'team', 'co', 'family', 'house']
# album
# ['lp', 'ep', 'cd', 'record', 'mixtape', 'song', 'soundtrack', 'songs']
# game
# ['match', 'play', 'player', 'team', 'sport', 'show', 'competition']
# district
# ['area', 'region', 'county', 'city', 'town', 'village', 'department', 'state']
# side
# ['team', 'end', 'back', 'front', 'club', 'part', 'face']
# county
# ['district', 'city', 'township', 'state', 'town', 'parish', 'prefecture', 'province']
# league
# ['conference', 'association', 'division', 'club', 'alliance', 'tournament', 'cup', 'championship']
# use
# ['utilize', 'utilized', 'work', 'have', 'utilization']
# west
# ['east', 'north', 'south', 'central', 'eastern', 'northeast']
# face
# ['head', 'eyes', 'body', 'voice', 'hand']
# government
# ['state', 'public', 'military', 'army', 'administration', 'country', 'authorities']
# march
# ['february', 'april', 'january', 'august', 'october', 'december', 'november', 'july', 'may']
# town
# ['city', 'village', 'community', 'local', 'country', 'district', 'county', 'area']
# june
# ['july', 'april', 'september', 'november', 'august', 'february', 'october', 'may', 'december']
# line
# ['group', 'service', 'system', 'series', 'area', 'house']

# %%
df_triples = pd.read_csv('./candidate_BERT.txt', sep = '\t', header= None, )
len(df_triples)
# Out:
# 2940

# %%
df_triples
# Out:
#                     0       1       2  3
# 0     AtLocation       time    day     2
# 1     AtLocation       day     time    2
# 2     IsA              time    day     2
# 3     IsA              day     time    2
# 4     HasPrerequisite  time    day     2
# 5     HasPrerequisite  day     time    2
# 6     HasA             time    day     2
# 7     HasA             day     time    2
# 8     PartOf           time    day     2
# 9     PartOf           day     time    2
# 10    AtLocation       time    it      2
# 11    AtLocation       it      time    2
# 12    IsA              time    it      2
# 13    IsA              it      time    2
# 14    HasPrerequisite  time    it      2
# 15    HasPrerequisite  it      time    2
# 16    HasA             time    it      2
# 17    HasA             it      time    2
# 18    PartOf           time    it      2
# 19    PartOf           it      time    2
# 20    AtLocation       time    one     2
# 21    AtLocation       one     time    2
# 22    IsA              time    one     2
# 23    IsA              one     time    2
# 24    HasPrerequisite  time    one     2
# 25    HasPrerequisite  one     time    2
# 26    HasA             time    one     2
# 27    HasA             one     time    2
# 28    PartOf           time    one     2
# 29    PartOf           one     time    2
# ...      ...           ...      ...   ..
# 2910  AtLocation       line    series  2
# 2911  AtLocation       series  line    2
# 2912  IsA              line    series  2
# 2913  IsA              series  line    2
# 2914  HasPrerequisite  line    series  2
# 2915  HasPrerequisite  series  line    2
# 2916  HasA             line    series  2
# 2917  HasA             series  line    2
# 2918  PartOf           line    series  2
# 2919  PartOf           series  line    2
# 2920  AtLocation       line    area    2
# 2921  AtLocation       area    line    2
# 2922  IsA              line    area    2
# 2923  IsA              area    line    2
# 2924  HasPrerequisite  line    area    2
# 2925  HasPrerequisite  area    line    2
# 2926  HasA             line    area    2
# 2927  HasA             area    line    2
# 2928  PartOf           line    area    2
# 2929  PartOf           area    line    2
# 2930  AtLocation       line    house   2
# 2931  AtLocation       house   line    2
# 2932  IsA              line    house   2
# 2933  IsA              house   line    2
# 2934  HasPrerequisite  line    house   2
# 2935  HasPrerequisite  house   line    2
# 2936  HasA             line    house   2
# 2937  HasA             house   line    2
# 2938  PartOf           line    house   2
# 2939  PartOf           house   line    2
#
# [2940 rows x 4 columns]

# %%
df_triples.columns = ('rel','head','tail','label')

# %%
df = pd.read_csv('./BERT_mining_pred_direct.csv', index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-f888352e9bcb> in <module>
# ----> 1 df = pd.read_csv('./BERT_mining_pred_direct.csv', index_col = 0)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./BERT_mining_pred_direct.csv' does not exist: b'./BERT_mining_pred_direct.csv'

# %%
df_triples['prob'] =  df.prob

# %%
groups = df_triples.groupby(by=['head','tail'])
df_filter = groups.apply(lambda g: g[g['prob'] == g['prob'].max()])
df_filter[df_filter.prob > 0.9999].to_csv('./sorted_BERT_direct.csv', index = False)
