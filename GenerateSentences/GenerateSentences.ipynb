# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from FilesToUploadToColab.experiments import DirectTemplate, EnumeratedTemplate, Experiment
from pytorch_pretrained_bert import BertForMaskedLM, GPT2LMHeadModel
import pandas as pd
from copy import deepcopy
import numpy as np

# %%
bert = BertForMaskedLM.from_pretrained('bert-large-uncased')
gpt = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
class KnowledgeMiner:
    def __init__(self, dev_data_path, device, Template, bert, template_loc = None, language_model = None):
        self.sentences_mask_tail = Template(
            dev_data_path, 
            False, 
            True, 
            device, 
            template_loc = template_loc, 
            language_model = language_model
        )
        self.sentences_mask_head = Template(
            dev_data_path, 
            True, 
            False, 
            device, 
            template_loc = template_loc, 
            language_model = language_model
        )
        self.sentences_mask_both = Template(
            dev_data_path,
            True,
            True, 
            device,
            template_loc = template_loc, 
            language_model = language_model
        )
        
        bert.eval()
        bert.to(device)
        self.bert = bert

        self.device = device
        self.results = []
    
    def make_predictions(self):
        data = []
        for idx, ((sent, masked_tail, ids, label), (_, masked_head, _, _), (_, masked_both, _, _)) \
                in enumerate(zip(self.sentences_mask_tail, self.sentences_mask_head, self.sentences_mask_both)):
            tail_masked_ids = [idx for idx, token in enumerate(masked_tail) if token == 103]
            head_masked_ids = [idx for idx, token in enumerate(masked_head) if token == 103]

            # conditional
            logprob_tail_conditional = self.predict(sent, masked_tail, ids, tail_masked_ids)
            logprob_head_conditional = self.predict(sent, masked_head, ids, head_masked_ids)
            # marginal
            logprob_tail_marginal = self.predict(sent, masked_both, ids, tail_masked_ids)
            logprob_head_marginal = self.predict(sent, masked_both, ids, head_masked_ids)

            NLL = -logprob_tail_conditional/len(tail_masked_ids)

            mutual_inf = logprob_tail_conditional - logprob_tail_marginal
            mutual_inf += logprob_head_conditional - logprob_head_marginal
            mutual_inf /= 2.
            try:
                print(idx, (NLL.item(), mutual_inf.item(), label, self.sentences_mask_tail.id_to_text(sent)))
                data.append((NLL.item(), logprob_tail_conditional.item(), logprob_tail_marginal.item(),
                             logprob_head_conditional.item(), logprob_head_marginal.item(),
                             mutual_inf.item(), label, self.sentences_mask_tail.id_to_text(sent)))
            except AttributeError:
                print(idx, (NLL, mutual_inf, label, self.sentences_mask_tail.id_to_text(sent)))
                data.append((NLL,  logprob_tail_conditional.item(), logprob_tail_marginal.item(),
                             logprob_head_conditional.item(), logprob_head_marginal.item(),
                             mutual_inf.item(), label, self.sentences_mask_tail.id_to_text(sent)))
        # prep data
        df = pd.DataFrame(data, columns = ('nll','tail_conditional','tail_marginal',
                                           'head_conditional','head_marginal','mut_inf','label','sent')) 
        self.results = df
        return df
    
    def predict(self, sent, masked, ids, masked_ids):
        print(masked_ids)
        logprob = 0
        masked = deepcopy(masked)
        masked_ids = masked_ids.copy()
        for _ in range(len(masked_ids)):
            # make prediction
            pred = self.bert(masked.reshape(1,-1),ids.reshape(1,-1)).log_softmax(2)
            
            # get log probs for each token
            max_log_prob = -np.inf
            
            for idx in masked_ids:
                if pred[0, idx, sent[idx]] > max_log_prob:
                    most_likely_idx = idx
                    max_log_prob = pred[0, idx, sent[idx]]
            
            logprob += max_log_prob
            masked[most_likely_idx] = sent[most_likely_idx]
            masked_ids.remove(most_likely_idx) 
            print(self.sentences_mask_tail.id_to_text(pred[0, most_likely_idx,:].topk(10)[1]))
            print(self.sentences_mask_tail.id_to_text(sent[most_likely_idx:most_likely_idx+1]))
        return logprob

# %%
ck_miner = KnowledgeMiner(
    '../FilesToUploadToColab/NovelTuples.csv', 
    'cpu', 
    EnumeratedTemplate, 
    bert, 
    language_model = gpt, 
    template_loc = '../FilesToUploadToColab/relation_map_multiple.json'
)

# %%
df = ck_miner.make_predictions()
# Out:
# [6, 7]
# are feel look can do sit get become will stand
# take
# notes care comfort pictures notice control it note action orders
# notice
# [3]
# do see notice look listen hear know watch work learn
# sit
# [6, 7]
# are were feel do go can get would will become
# take
# it care risks control action everything advantage life them charge
# notice
# [3]
# die do sleep can run fall live fight want come
# sit
# 0 (4.850859642028809, 1.0750312805175781, 11, '[CLS] when you sit , you take notice . [SEP]')
# [7]
# burn grow heal survive rain dry die bleed soil weep
# temperature
# [3, 4]
# cold hot warm here up out heat outside wet water
# moisture
# see find smell feel get have need taste lose want
# soil
# [7]
# die run know fight live sleep think kill listen change
# temperature
# [3, 4]
# were are get see want need got feel saw have
# soil
# yourself it ##ed themselves something myself them yourselves up someone
# moisture
# 1 (11.350737571716309, 2.0678091049194336, 9, '[CLS] when you soil moisture , you temperature . [SEP]')
# [9, 10]
# up out high money it strong power old down something
# growth
# see feel think realize do want consider sense know say
# population
# [12]
# stop change research exercise think control education counting listen trade
# increasing
# [9, 10]
# old up older out young home hungry angry here it
# growth
# see do feel experience want have enjoy need start stop
# population
# [12]
# think sleep talk forget relax work fight eat run listen
# increasing
# 2 (10.08566665649414, 5.940576553344727, 19, '[CLS] one of the things you do when you population growth is increasing . [SEP]')
# [9, 10]
# out up it old here young older there one drunk
# history
# study read write make do learn research create understand know
# art
# [13]
# math reading same library study following writing homework research opposite
# term
# [9, 10]
# up old out older home young it here high hungry
# history
# study make write read learn create research change watch understand
# art
# [13]
# following opposite same reading job truth work exercise study talking
# term
# 3 (9.665913581848145, 1.478346347808838, 10, '[CLS] one of the things you do when you art history is the term . [SEP]')
# [8, 9]
# gold silver black golden good red white best great blue
# silver
# one man coin tongue coins ones fish star ##fish heart
# mining
# [4]
# gold mining silver mine miners miner mines copper money land
# gold
# [8, 9]
# first best only great good true most new the one
# silver
# lining one tongue fox heart man bullet dollar ones wolf
# mining
# [4]
# first man best last king day fool same brave lord
# gold
# 4 (6.7198920249938965, 6.035772323608398, 16, '[CLS] when you the gold , you the silver mining . [SEP]')
# [6, 7]
# air breathe fire light breath sound live it fly alive
# pollution
# get smell create breathe feel cause catch experience have see
# noise
# [3]
# smoke breathe sing roar scream talk noise die drink hear
# air
# [6, 7]
# are were feel do go can get would will become
# noise
# ##less change ##lessly out it alone me bleed stuff play
# pollution
# [3]
# die do sleep can run fall live fight want come
# air
# 5 (10.405967712402344, 1.286224603652954, 19, '[CLS] when you air , you noise pollution . [SEP]')
# [7]
# win lose run play skate die score fall cheer fight
# ice
# [3, 4]
# cold hot ice frozen snow hard wet hungry warm angry
# hockey
# play watch played do see like start hate shoot plays
# roller
# [7]
# die run know fight live sleep think kill listen change
# ice
# [3, 4]
# hungry tired it alone there angry up ready happy out
# hockey
# play played watch start do like plays see lose hate
# roller
# 6 (10.324063301086426, 1.7423605918884277, 9, '[CLS] when you roller hockey , you ice . [SEP]')
# [6, 7]
# better good play lose it live win great yourself everything
# league
# play make get win have talk know understand like run
# hockey
# [3]
# play win fight hockey skate go come lose can do
# play
# [6, 7]
# strong out stronger it better good free alive happy different
# league
# play have are were say played make got get said
# hockey
# [3]
# die do sleep can run fall live fight want come
# play
# 7 (12.90212345123291, 2.351672410964966, 7, '[CLS] when you play , you hockey league . [SEP]')
# [9]
# wind power water sea light sun rain air storm thunder
# energy
# [4, 5]
# time power is you people water day man place light
# power
# will the physical real great energy same power spiritual your
# wind
# [9]
# best man better same first king greatest last leader fool
# energy
# [4, 5]
# man sun world lord one heart boy wind king day
# wind
# blows rises dies blow comes moves changes breaks shifts blowing
# power
# 8 (4.94287109375, 3.9508728981018066, 17, '[CLS] when you the wind power , you the energy . [SEP]')
# [8]
# belong live die lead know see shine change sing play
# process
# [3, 5]
# have take see get hit make find enter read touch
# be
# vampire kid student child human cop doctor soldier parent wolf
# part
# [8]
# run die fight kill know live change win listen lose
# process
# [3, 5]
# have were need want had see are find get hit
# be
# man boy girl vampire child woman kid soldier wolf father
# part
# 9 (9.144815444946289, 0.6256880760192871, 12, '[CLS] when you be a part , you process . [SEP]')
# [6, 7]
# rescue help save are find take get give kill protect
# law
# them it him you me ##less ##breakers breakers enforcement us
# enforcement
# [3]
# do can work kill run come die land win want
# rescue
# [6, 7]
# are were feel do go can get would will become
# law
# them it me you him people us ##less ##breakers enforcement
# enforcement
# [3]
# die do sleep can run fall live fight want come
# rescue
# 10 (8.040825843811035, 0.8448705673217773, 15, '[CLS] when you rescue , you law enforcement . [SEP]')
# [13]
# following opposite same reading work eating job talking truth taking
# commitment
# [9, 10]
# get become are have make find go start take grow
# job
# , security out in work before offer it is ##less
# satisfaction
# [13]
# following opposite same reading job truth work exercise study talking
# commitment
# [9, 10]
# are get become go have make grow were do take
# job
# , out security here overseas work there is today up
# satisfaction
# 11 (9.165464401245117, 0.00331878662109375, 13, '[CLS] one of the things you do when you job satisfaction is the commitment . [SEP]')
# [6, 7]
# are will become can do get must feel have go
# carbon
# ##ize ##ate dioxide burn ##ify ##e ##ized ##ite black ##ation
# dioxide
# [3]
# breathe die burn live freeze grow smoke heat fly eat
# activity
# [6, 7]
# are were feel do go can get would will become
# carbon
# ##ate ##ize ##e dioxide ##ite ##ify you ##ation burn mine
# dioxide
# [3]
# die do sleep can run fall live fight want come
# activity
# 12 (7.404740810394287, 1.197770118713379, 12, '[CLS] when you activity , you carbon dioxide . [SEP]')
# [10, 11, 12, 13, 14, 15, 16]
# ) " ##mine ##m ' ##me one drug drugs system
# ##er
# drink cheat block ring sinn think transport bind talk send
# transport
# drug energy drugs sugar brain cell same dose system the
# nor
# - ##i , ##in . ##t ##ian ' ##c ##o
# ##ep
# ##am ##ac ##ic ##athy ##ame ##ian ##atic ##amina ##ox ##in
# ##ine
# ##mine ##amine ##l a - ##ural ##mia ##zin in ,
# ##rine
# ##ph ##bu lu ##ct mu tau ed ##cta ##vale ##fera
# ##ph
# [4, 5, 6]
# drug body blood sugar drugs heart brain cell first enzyme
# do
# ##pe ##pa ##xy - ##h ##r ##pants ##le ##uche ##p
# ##pa
# ##mine ##min ##mate ##m ##mide ##zone ##h mater is ##tase
# ##mine
# [10, 11, 12, 13, 14, 15, 16]
# man one heart child world tree woman boy earth king
# ##er
# sinn drink think find say wear suffer wander dwell labor
# transport
# ship one power player you human body man person first
# nor
# , is . ##t are ' ##s - ##k and
# ##ine
# ##bert ##ef ##ent ##bil ##od ##ev ##eng ##ed ##bra ##for
# ##ep
# ##l ##um ##al ##ural ##tic ##ment ##tal ##ne ##mal ##cular
# ##rine
# ##ph ##th ##ct mu ##thy tau ##vale ##pha ##ng ##pt
# ##ph
# [4, 5, 6]
# king man one lord sun boy world devil child moon
# do
# not you the it so - this ##pe is that
# ##pa
# ##mine ##h ##mo ##ble ##m ##min ##ma ##me do ##mi
# ##mine
# 13 (5.593106746673584, 9.782342910766602, 7, '[CLS] when you the do ##pa ##mine , you the nor ##ep ##ine ##ph ##rine transport ##er . [SEP]')
# [7]
# freeze melt burn die drink win chill froze eat float
# surface
# [3, 4]
# are get go become fall feel do break die grow
# water
# out it ##tight ##proof deep down jump off me them
# ice
# [7]
# die run know fight live sleep think kill listen change
# surface
# [3, 4]
# were are get see want need got feel saw have
# water
# yourself it them down up me off yourselves out this
# ice
# 14 (9.685440063476562, 1.761786937713623, 23, '[CLS] when you water ice , you surface . [SEP]')
# [7]
# write dream die wonder know believe laugh love live read
# success
# [3, 4]
# were are get see have want feel got saw need
# science
# work learn fail show study test believe progress experiment play
# fiction
# [7]
# die run know fight live sleep think kill listen change
# success
# [3, 4]
# were are get see want need got feel saw have
# science
# class learn teach it work me fail yourself fiction people
# fiction
# 15 (9.481706619262695, -0.5286884307861328, 9, '[CLS] when you science fiction , you success . [SEP]')
# [6, 7]
# buy sell get pay look make shop do go eat
# post
# orders advertisements flyers it them messages ads advertising cards posters
# office
# [3]
# come leave arrive land pay write go call do sign
# shop
# [6, 7]
# are were feel do go can get would will become
# post
# it messages posts them posters guards notes orders advertisements cards
# office
# [3]
# die do sleep can run fall live fight want come
# shop
# 16 (10.592296600341797, 0.9979822635650635, 38, '[CLS] when you shop , you post office . [SEP]')
# [7]
# die change are live exist matter know burn go grow
# carbon
# [3, 4]
# carbon gold light iron it water air steel hard dust
# atom
# say are see find hit touch have become make am
# hydrogen
# [7]
# die run know fight live sleep think kill listen change
# carbon
# [3, 4]
# hungry tired it alone there angry up ready happy out
# atom
# see say are find touch reach become hit am have
# hydrogen
# 17 (7.925844192504883, 6.316428184509277, 10, '[CLS] when you hydrogen atom , you carbon . [SEP]')
# [7]
# code write build work change create test buy develop produce
# use
# [3, 4]
# need something want it money up out them power love
# software
# need want have build create find get make use write
# source
# [7]
# die run know fight live sleep think kill listen change
# use
# [3, 4]
# were are get see want need got feel saw have
# source
# information something it money them data energy power things people
# software
# 18 (4.744879722595215, 1.8160762786865234, 8, '[CLS] when you source software , you use . [SEP]')
# [9, 10, 11, 12, 13]
# b ##1 1 ) ##2 protein ##3 molecule a ##n
# subunit
# alpha b beta α first β second catalytic a gamma
# ##genase
# trans hydro aldo mono de halo retro auto alpha meta
# ##dro
# den ##hy nad flu coa al syn cal fly er
# ##hy
# de di auto trans hyper photo an bio super mono
# de
# [3, 4, 5, 6]
# enzyme complex cycle enzymes pathway system reaction ##1 gene ##ase
# b
# vitamin enzyme type complex protein sugar factor subunit class group
# ##chrome
# mono hydro proto tri auto eu aldo homo mega poly
# ##to
# cy ke his ci ##cy pen gene ec mo che
# cy
# [9, 10, 11, 12, 13]
# thing idea one look man person time problem day chance
# subunit
# have see find are get enter become use add receive
# de
# - ##grade ##dicate ##base ##pose facto ##code ##press ##ducted ##port
# ##hy
# ##de ##d ##drop ##ded ##date ##erate ##pate ##dron ##del ##des
# ##dro
# ##genase - ##gen ##fy ##fying ##genic ##phobic ##ze ##grade ##fies
# ##genase
# [3, 4, 5, 6]
# ##r ##d ##t ##rd ##rium ##ring ##l ##g ##m ##wing
# b
# the a plan type class option one group side part
# ##chrome
# see have use read watch saw get got want find
# cy
# ##to ##tos ##ano ##mbo ##bro ##mo ##sto ##so ##no ##do
# ##to
# 19 (5.57363748550415, 12.459952354431152, 9, '[CLS] when you cy ##to ##chrome b , you de ##hy ##dro ##genase subunit . [SEP]')
# [6, 7]
# company talk alone yourself quiet trust share work live love
# service
# provide do give need have offer get receive render require
# bus
# [3]
# leave travel work go come arrive can do call die
# company
# [6, 7]
# strong out stronger it better good free alive happy different
# service
# get give need do provide have offer receive expect got
# bus
# [3]
# die do sleep can run fall live fight want come
# company
# 20 (9.574834823608398, 3.8075103759765625, 12, '[CLS] when you company , you bus service . [SEP]')
# [6, 8]
# become have need get feel are find take carry make
# take
# nap breath break drink shower rest bath pill risk walk
# place
# [3]
# die go do come fall leave start win choose move
# rest
# [6, 8]
# are have become were became get need see had make
# take
# drink break risk shower breath nap chance bath shot piss
# place
# [3]
# die do died sleep kill run fall fight drink win
# rest
# 21 (6.214040756225586, -0.1717393398284912, 7, '[CLS] when you rest , you take a place . [SEP]')
# [8, 9]
# ball game player team is play man bat run pitcher
# team
# baseball football other ball home softball basketball first soccer winning
# softball
# [4]
# ball game team girls player coach players pitcher season field
# baseball
# [8, 9]
# one man is ones come die dance live will are
# team
# best good winning first better whole other home second the
# softball
# [4]
# first man best last king day fool same brave lord
# baseball
# 22 (3.778607130050659, 8.190752983093262, 7, '[CLS] when you the baseball , you the softball team . [SEP]')
# [8, 9]
# are get have will pay can do become be got
# d
# go ' pay ##y know say do come rest leave
# ##m
# [4, 5]
# time man day boy first party doctor king last army
# capita
# ##n ##ine ##tion ##te ##r ##t ##ry ##nte ##in ##ne
# allowance
# [8, 9]
# are will become were go the do can must get
# d
# know go die come sleep think call be ' talk
# ##m
# [4, 5]
# die come fall move comes is go change are dies
# allowance
# same monthly first money extra full daily last least food
# capita
# 23 (8.589866638183594, -0.4362974166870117, 8, '[CLS] when you the capita allowance , you d ##m . [SEP]')
# [9, 10, 11]
# , it life again power one control someone people yourself
# poisoning
# food alcohol lead blood the radiation mercury a chemical arsenic
# ##xide
# hydro mono ##tro eu ##to mo halo an macro poly
# mono
# [13]
# sleep talk think forget stop eat work panic exercise relax
# death
# [9, 10, 11]
# , one money it person people man town home here
# poisoning
# food alcohol lead radiation blood mercury occupational the silver iron
# ##xide
# hydro mono ##tro eu ##to macro an halo radio trio
# mono
# [13]
# think relax sleep talk forget run listen exercise work eat
# death
# 24 (8.940866470336914, 0.7821342945098877, 8, '[CLS] one of the things you do when you mono ##xide poisoning is death . [SEP]')
# [7, 8]
# it out there go yourself up ready in you inside
# theme
# the play sing say have use follow make start a
# ending
# [4]
# end song last ending day love time first best final
# opening
# [7, 8]
# it good better you yourself ready free there me happy
# theme
# the a are have make create become see play get
# ending
# [4]
# day time first same best last man sun moment night
# opening
# 25 (10.560914993286133, 3.1159090995788574, 7, '[CLS] when you the opening , you ending theme . [SEP]')
# [7]
# die burn change disappear kill fade decay heal live end
# emission
# [3, 4]
# it there out here this that one you him them
# decay
# do slowly ... truly first can will are really die
# beta
# [7]
# die run know fight live sleep think kill listen change
# emission
# [3, 4]
# hungry tired it alone there angry up ready happy out
# decay
# do feel truly ... slowly see can face will really
# beta
# 26 (13.944562911987305, 2.678010940551758, 16, '[CLS] when you beta decay , you emission . [SEP]')
# [7]
# write burn change drive pay download copy connect save play
# system
# [3, 4]
# were are get see want need have feel got saw
# flash
# it them again out back away ahead up forward lightning
# drive
# [7]
# die run know fight live sleep think kill listen change
# system
# [3, 4]
# were are get see want need got feel saw have
# flash
# again out back them away it forward lightning ahead up
# drive
# 27 (9.53242301940918, 1.1406912803649902, 10, '[CLS] when you flash drive , you system . [SEP]')
# [7]
# drink die eat win know lose change stop do are
# wine
# [3, 4]
# hungry home up here food not happy together out alone
# content
# are feel were felt become am get grow seem look
# alcohol
# [7]
# die run know fight live sleep think kill listen change
# wine
# [3, 4]
# hungry tired it alone there angry up ready happy out
# content
# were are feel felt get became was become am seem
# alcohol
# 28 (7.445132255554199, 1.5637731552124023, 7, '[CLS] when you alcohol content , you wine . [SEP]')
# [9, 10]
# out up it live dance young old high fight work
# premiere
# hit play do see watch film say shoot make press
# season
# [12]
# watch wait prepare smile listen audition write clap sing relax
# show
# [9, 10]
# are become get go have make were do find grow
# season
# them it up something someone yourself things people fish out
# premiere
# [12]
# think sleep talk forget relax work fight eat run listen
# show
# 29 (10.179920196533203, 2.3008933067321777, 13, '[CLS] one of the things you do when you season premiere is show . [SEP]')
# [7]
# change die lose grow survive adapt do know disappear kill
# warming
# [3, 4]
# happy hungry up good ready there here out together hard
# change
# do can really first ... did must truly actually all
# climate
# [7]
# die run know fight live sleep think kill listen change
# warming
# [3, 4]
# hungry tired it alone there angry up ready happy out
# change
# do can really first did ... need must could actually
# climate
# 30 (9.85317611694336, 2.630490779876709, 63, '[CLS] when you climate change , you warming . [SEP]')
# [7]
# win play lose coach learn watch know shine fight change
# team
# [3, 4]
# together out up teams one it team here there fighting
# coach
# play can are need call say become want have get
# basketball
# [7]
# die run know fight live sleep think kill listen change
# team
# [3, 4]
# hungry tired it alone there angry up ready happy out
# coach
# play were become are make lose need played see change
# basketball
# 31 (7.0933074951171875, 4.0369391441345215, 7, '[CLS] when you basketball coach , you team . [SEP]')
# [7]
# swim drown run live die see fall know go drowned
# water
# [3, 4]
# wet water hot up out clean cold high rain hard
# lake
# say are see call am go have find drink hit
# freshwater
# [7]
# die run know fight live sleep think kill listen change
# water
# [3, 4]
# hungry tired it alone there angry up ready happy out
# lake
# see saw say were find hear have met are lose
# freshwater
# 32 (4.986189365386963, 4.495392799377441, 8, '[CLS] when you freshwater lake , you water . [SEP]')
# [8]
# graduate leave change learn teach go stay apply pay start
# master
# [3, 5]
# master man slave leader student teacher child warrior soldier servant
# program
# start have complete learn run do create write enter build
# graduate
# [8]
# run die fight kill know live change win listen lose
# master
# [3, 5]
# vampire man woman girl human child kid wolf gun problem
# program
# start have run started see enter entered watch use had
# graduate
# 33 (9.928685188293457, 0.5583052635192871, 7, '[CLS] when you graduate a program , you master . [SEP]')
# [12]
# research work feedback math think exercise study editing talk practice
# user
# [9, 10]
# up out drink awake it run drive work live sleep
# programming
# do are start get have stop finish learn go practice
# application
# [12]
# think sleep talk forget relax work fight eat run listen
# user
# [9, 10]
# old up older out young home hungry angry here it
# programming
# do start are get learn enter have leave stop finish
# application
# 34 (11.387242317199707, 3.0581841468811035, 8, '[CLS] one of the things you do when you application programming is user . [SEP]')
# [7]
# heal relax cry run sleep panic break fight think change
# rate
# [3, 4]
# up out high it money one hard right low something
# stress
# feel have experience see face get sense encounter hit lose
# shear
# [7]
# die run know fight live sleep think kill listen change
# rate
# [3, 4]
# hungry tired it alone there angry up ready happy out
# stress
# feel have experience get felt face had see need experienced
# shear
# 35 (10.713665008544922, 0.35550737380981445, 11, '[CLS] when you shear stress , you rate . [SEP]')
# [7]
# fly fight jump land shoot sleep go live kill die
# aircraft
# [3, 4]
# are fly get were see go have land come do
# air
# travel it them power drop ##worthy ##drop force transport meet
# base
# [7]
# die run know fight live sleep think kill listen change
# aircraft
# [3, 4]
# were are get see want need got feel saw have
# air
# out up it in dry them breathe away ##time travel
# base
# 36 (8.236939430236816, 5.454358100891113, 15, '[CLS] when you air base , you aircraft . [SEP]')
# [6, 8]
# story lot person character feeling camera soundtrack message moment crowd
# song
# write sing have play create make hear get do record
# hit
# [3]
# play sing dance move hit do work write try run
# film
# [6, 8]
# are have become were became get need see had make
# hit
# wall target tree rock person barrier button hole building nerve
# song
# [3]
# die do died sleep kill run fall fight drink win
# film
# 37 (6.3142194747924805, 0.999025821685791, 9, '[CLS] when you film , you hit a song . [SEP]')
# [7]
# experiment know test learn change think work try understand do
# choice
# [3, 4]
# are want choose see get have do find need make
# set
# out off them up sail it forth down yourself eyes
# theory
# [7]
# die run know fight live sleep think kill listen change
# choice
# [3, 4]
# were are get see want need got feel saw have
# set
# out off sail up down foot them it forth about
# theory
# 38 (10.472902297973633, 0.2569541931152344, 33, '[CLS] when you set theory , you choice . [SEP]')
# [7]
# play win run fight skate score lose shine shoot cheer
# football
# [3, 4]
# football play running here go out you home it run
# hockey
# play played watch do like see plays have hate are
# ice
# [7]
# die run know fight live sleep think kill listen change
# football
# [3, 4]
# hungry tired it alone there angry up ready happy out
# hockey
# play played watch start do like plays see lose hate
# ice
# 39 (8.862543106079102, 5.1535773277282715, 53, '[CLS] when you ice hockey , you football . [SEP]')
# [12, 13]
# apology explanation act escape exercise education ##esthesia orgasm interview investigation
# attempt
# escape assassination suicide unsuccessful ambush endurance execution escaped evacuation honest
# assassination
# [9]
# die lose meet fail run win kill fight fall leave
# survivor
# [12, 13]
# one exercise smile job prayer massage apology act dance orgasm
# attempt
# assassination escape endurance unsuccessful honest actual ambush unconscious ob outside
# assassination
# [9]
# sleep die fly travel run fight heal work fall drink
# survivor
# 40 (3.9366159439086914, 0.21262741088867188, 15, '[CLS] one of the things you do when you survivor is an assassination attempt . [SEP]')
# [9]
# die fight travel go change join come live leave sing
# trilogy
# [11, 12]
# make get create write be play do to read a
# be
# creative patient funny honest realistic careful clever yourself ##ware original
# part
# [9]
# sleep die fly fight heal run travel fall win cry
# trilogy
# [11, 12]
# be make do get become eat call take to go
# be
# patient strong quiet careful prepared polite yourself alert still happy
# part
# 41 (12.695136070251465, -0.45583438873291016, 7, '[CLS] one of the things you do when you trilogy is be part . [SEP]')
# [9]
# travel die leave go retire visit come vacation graduate fly
# coaster
# [12, 13]
# loop line spin drop thing jump roll turn slide pass
# park
# amusement water theme skate car fun ride terrain air trailer
# amusement
# [9]
# sleep die fly fight run travel win work heal train
# coaster
# [12, 13]
# next first water blood last air sleep right exercise reading
# amusement
# park ##s ride system shop parks room game rides party
# park
# 42 (14.260333061218262, 0.9866480827331543, 9, '[CLS] one of the things you do when you coaster is the amusement park . [SEP]')
# [10]
# have get say know find are see obtain prove let
# fourier
# [3, 4, 5, 6, 7]
# are were go get have come ' start stop got
# con
# ##tour ##fer ##fide ##jure ##cede ##st ##jured ##t ##s ##founded
# ##vo
# ##ke - ##l ##lu ##c ##lge , ' ##lved ##k
# ##lu
# ##te ##ted ##tion ##tes ##ate ##ting ##ture ##to ##ze ##tively
# ##tion
# occur ##al ##ize ##ed ##e ##ate are function ##es ##ation
# theorem
# [10]
# know die change knew see understand run remember changed fall
# fourier
# [3, 4, 5, 6, 7]
# were go are come get came start went got stop
# con
# ##fide ##jured ##fer ##tour ##jure ##st ##cede ##cu ##founded ##t
# ##vo
# ##ke ##lu ##l - ##ked ##c ##lun ##lge ##id ##lved
# ##lu
# ##te ##ted ##tion ##tes ##ate ##ting ##ated ##ture ##ze ##t
# ##tion
# ##ed together die occur yourself again ##ize do it ##al
# theorem
# 43 (12.13080883026123, 4.1303277015686035, 8, '[CLS] when you con ##vo ##lu ##tion theorem , you fourier . [SEP]')
# [7]
# work kill police fight listen run know protect patrol pay
# period
# [3, 4]
# get are go have do become feel were want see
# law
# it them me you him enforcement work this us matters
# enforcement
# [7]
# die run know fight live sleep think kill listen change
# period
# [3, 4]
# were are get see want need got feel saw have
# law
# it them me people someone him ##men you ##breakers ##less
# enforcement
# 44 (11.597675323486328, 0.1253957748413086, 8, '[CLS] when you law enforcement , you period . [SEP]')
# [6, 7]
# power control it good change love strength live yourself fire
# engine
# are have drive use control need run get sound make
# v8
# [3]
# run drive die start roar turn work go race win
# power
# [6, 7]
# strong out stronger it better good free alive happy different
# engine
# see hear say have said are mean need get were
# v8
# [3]
# die do sleep can run fall live fight want come
# power
# 45 (12.894832611083984, 2.209825277328491, 7, '[CLS] when you power , you v8 engine . [SEP]')
# [9, 10]
# sleep eat die feed drink awake come live heal can
# series
# watch do make have win host get start see join
# television
# [12]
# watch dance sing talk write audition listen work smile entertain
# host
# [9, 10]
# old up older out young home hungry angry here it
# series
# write make do watch read create produce have like sell
# television
# [12]
# think sleep talk forget relax work fight eat run listen
# host
# 46 (10.711282730102539, 3.2334110736846924, 16, '[CLS] one of the things you do when you television series is host . [SEP]')
# [6, 7]
# it think idea do know believe something yourself act thinking
# system
# think use are say mean have get create do become
# operating
# [3]
# run work write start call do boot die load drive
# idea
# [6, 7]
# strong out stronger it better good free alive happy different
# system
# have use need got are get used had know do
# operating
# [3]
# die do sleep can run fall live fight want come
# idea
# 47 (10.167510986328125, 1.6200227737426758, 10, '[CLS] when you idea , you operating system . [SEP]')
# [8, 9]
# quality value is one ##ness good price thing person means
# satisfaction
# the most greatest highest more best great take maximum ultimate
# customer
# [4]
# customer customers business product best sales satisfaction price service money
# quality
# [8, 9]
# first best only great good true most new the one
# customer
# is pays too comes knows now again here service first
# satisfaction
# [4]
# first man best last king day fool same brave lord
# quality
# 48 (6.522777080535889, 5.288991928100586, 7, '[CLS] when you the quality , you the customer satisfaction . [SEP]')
# [6, 7]
# not speak state lie talk correct think it say act
# squad
# make join play say are have form call get become
# firing
# [3]
# die shoot kill come fire land fight do win strike
# state
# [6, 7]
# strong out stronger it better good free alive happy different
# squad
# make are join become play were made get hit say
# firing
# [3]
# die do sleep can run fall live fight want come
# state
# 49 (10.973553657531738, 1.8559975624084473, 8, '[CLS] when you state , you firing squad . [SEP]')
# [7]
# experiment know test learn change think work try understand do
# logic
# [3, 4]
# logic reason it sense you thinking thought math science truth
# theory
# use have want do say take need are understand like
# set
# [7]
# die run know fight live sleep think kill listen change
# logic
# [3, 4]
# were are get see want need got feel saw have
# set
# out off sail up down foot them it forth about
# theory
# 50 (7.111623764038086, 5.595054626464844, 31, '[CLS] when you set theory , you logic . [SEP]')
# [7, 8]
# weather climate temperature it people heat environment life geography everything
# ##a
# can must do are sort re get mean should have
# cw
# [3, 4]
# back home out there here up ready it go leave
# climate
# say mean said do use call add define have are
# koppen
# [7, 8]
# strong happy stronger good alive different beautiful alone better free
# ##a
# fell sort suck will must ought should can add call
# cw
# [3, 4]
# hungry tired angry here there happy alone old it out
# climate
# say see define change know understand find have call do
# koppen
# 51 (10.773418426513672, 1.5580387115478516, 7, '[CLS] when you koppen climate , you cw ##a . [SEP]')
# [9, 10]
# are get become go leave do have make come find
# law
# it them people someone me us yourself , something him
# enforcement
# [13]
# truth paperwork same following job interview internet reading best fbi
# world
# [9, 10]
# are get become go have make grow were do take
# law
# them it enforcement people me someone school us ##less firm
# enforcement
# [13]
# following opposite same reading job truth work exercise study talking
# world
# 52 (9.020172119140625, -2.063126564025879, 7, '[CLS] one of the things you do when you law enforcement is the world . [SEP]')
# [6, 7]
# are get become will do can keep feel make have
# rail
# hard it forward away harder along ##ward back against on
# link
# [3]
# travel run connect go train come land move can fly
# speed
# [6, 7]
# are were feel do go can get would will become
# rail
# back away ##ed ##er harder outward on out hard against
# link
# [3]
# die do sleep can run fall live fight want come
# speed
# 53 (12.32886028289795, 2.8221068382263184, 7, '[CLS] when you speed , you rail link . [SEP]')
# [9, 10]
# home up here out college school there older young back
# hockey
# play watch like are do love hate go practice played
# ice
# [12, 13]
# play run score talk dance it smile out whistle cheer
# hockey
# play ice street field skate stop water kick stick shoot
# field
# [9, 10]
# up old older out young it home here hungry high
# hockey
# play watch do coach practice quit played like start lose
# ice
# [12, 13]
# make do be get become eat take call to create
# field
# research work ##work hockey training maintenance walking ops surveillance shooting
# hockey
# 54 (9.359960556030273, 1.5099225044250488, 20, '[CLS] one of the things you do when you ice hockey is field hockey . [SEP]')
# [8]
# belong live die lead know see shine change sing play
# line
# [3, 5]
# have see get want need find make hear hit are
# be
# man girl dancer boy woman soldier child kid horse sailor
# part
# [8]
# run die fight kill know live change win listen lose
# line
# [3, 5]
# have were need want had see are find get hit
# be
# man boy girl vampire child woman kid soldier wolf father
# part
# 55 (10.529162406921387, 0.6824016571044922, 12, '[CLS] when you be a part , you line . [SEP]')
# [6, 7]
# it mail me everything nothing text call email send them
# name
# change give write send have add use get just say
# domain
# [3]
# name register search registered call vote speak visit do sign
# mail
# [6, 7]
# strong out stronger it better good free alive happy different
# name
# can must will take say have know give need lose
# domain
# [3]
# die do sleep can run fall live fight want come
# mail
# 56 (10.007518768310547, 4.5066142082214355, 22, '[CLS] when you mail , you domain name . [SEP]')
# [7]
# fail succeed die kill win benefit help suffer lose gain
# use
# [3, 4]
# want need have find see are get can like do
# harm
# someone others people yourself another them me anyone her something
# reduction
# [7]
# die run know fight live sleep think kill listen change
# use
# [3, 4]
# were are get see want need got feel saw have
# harm
# someone others yourself her people them another me him anyone
# reduction
# 57 (6.481059551239014, -0.7582390308380127, 9, '[CLS] when you harm reduction , you use . [SEP]')
# [6, 7]
# are get will can go do were must stay have
# air
# it them away out travel up me ##mail back fast
# base
# [3]
# land fly jump attack fall run do fight arrive come
# airport
# [6, 7]
# are were feel do go can get would will become
# air
# out it up them dry away breathe in me clean
# base
# [3]
# die do sleep can run fall live fight want come
# airport
# 58 (7.189606666564941, 3.119675636291504, 11, '[CLS] when you airport , you air base . [SEP]')
# [6, 7]
# play are sing do can be sound will have go
# music
# yourself play itself you live it alone them themselves me
# theory
# [3]
# play sing write dance work listen learn love teach do
# piano
# [6, 7]
# are were feel do go can get would will become
# music
# itself you play plays matters them it me sounds is
# theory
# [3]
# die do sleep can run fall live fight want come
# piano
# 59 (7.0208282470703125, 5.25693941116333, 11, '[CLS] when you piano , you music theory . [SEP]')
# [8]
# stop sign wait run call signal go know listen move
# time
# [3, 5]
# have need are get want got make see do take
# call
# time game meeting halt thing man friend truce lot day
# sign
# [8]
# run die fight kill know live change win listen lose
# time
# [3, 5]
# have were need want had see are find get hit
# call
# dog cab bluff girl truce man number halt friend party
# sign
# 60 (10.956602096557617, 0.3547024726867676, 7, '[CLS] when you call a sign , you time . [SEP]')
# [6, 7, 8]
# can are will have do get see must ' say
# rf
# ##id ##d ##s ##p ##t ##m ##f ##i ##l ##x
# ##ulator
# mod ins em und im ed act ann reform in
# mod
# [3]
# transmit am move run do are start push operate pulse
# video
# [6, 7, 8]
# it me out them you alone more up here again
# ##ulator
# mod em ins und im tab sim spec ad ul
# mod
# are use have call get see become say need make
# rf
# [3]
# die do fall can sleep run live died leave come
# video
# 61 (7.55234956741333, 2.6590709686279297, 11, '[CLS] when you video , you rf mod ##ulator . [SEP]')
# [6, 7]
# are become will feel must go leave do can fall
# reform
# yourself yourselves together me it them him again completely quickly
# movement
# [3]
# reform win can fight change do go die succeed work
# part
# [6, 7]
# are were feel do go can get would will become
# reform
# yourself them it quickly completely people again me him themselves
# movement
# [3]
# die do sleep can run fall live fight want come
# part
# 62 (11.425189971923828, -0.7350168228149414, 7, '[CLS] when you part , you reform movement . [SEP]')
# [11]
# variance matrix mean vector inverse density product function correlation kernel
# ensemble
# [4, 5, 6, 7]
# group ensemble band one whole music individual orchestra song single
# co
# ##s ##e ##o ##a ##es ##t ##y ##re ##us ##r
# matrix
# - ##hesion ##r ##hesive ##hn ##hort ##set ##spar ##rt ##g
# ##var
# ##iance ##icative ##ization ##iation ##iate ##ification ##iable ##ian ##ity ##ie
# ##iance
# [11]
# best man king lord same first one day better last
# ensemble
# [4, 5, 6, 7]
# lord sun one man first world day heart light king
# co
# - ##on ##g ##r ##smo ##sy ##rr ##o ##y ##s
# ##var
# ##ies ##iance ##iable ##iate ##ian ##s ##i ##ia ##ie ##icate
# ##iance
# is ##s becomes exists of increases occurs function changes ,
# matrix
# 63 (6.910522937774658, 1.784475564956665, 7, '[CLS] when you the co ##var ##iance matrix , you the ensemble . [SEP]')
# [6, 8]
# get make have are do create become draw hit take
# see
# light star face pattern monster person ghost shadow hole man
# section
# [3]
# look focus turn move stop search do stand walk enter
# line
# [6, 8]
# are have become were became get need see had make
# see
# light ghost monster face star lot pattern shadow person man
# section
# [3]
# die do died sleep kill run fall fight drink win
# line
# 64 (7.207358360290527, 0.23389434814453125, 9, '[CLS] when you line , you see a section . [SEP]')
# [6, 7]
# are will die become be go must shall stay am
# take
# care it everything control blood risks life action charge them
# possession
# [3]
# want do come can need fight kill take touch die
# death
# [6, 7]
# are were feel do go can get would will become
# take
# it care risks control action everything advantage life them charge
# possession
# [3]
# die do sleep can run fall live fight want come
# death
# 65 (6.135041236877441, -1.1153221130371094, 8, '[CLS] when you death , you take possession . [SEP]')
# [6, 7]
# are will do can say signal get must call go
# phase
# out back forward ahead off away it in again through
# shift
# [3]
# die change fall land jump do move shift transform sleep
# signal
# [6, 7]
# strong out stronger it better good free alive happy different
# shift
# can will must cannot just never always do only also
# phase
# [3]
# die do sleep can run fall live fight want come
# signal
# 66 (7.845973968505859, 3.7769007682800293, 7, '[CLS] when you signal , you phase shift . [SEP]')
# [7]
# win won lose fight shine start wins lost do go
# bout
# [3, 4]
# are get do be bout see like say go want
# world
# is comes go come came , goes day was begins
# title
# [7]
# die run know fight live sleep think kill listen change
# bout
# [3, 4]
# were are get see want need got feel saw have
# world
# ends changes falls change comes end begins fall exists starts
# title
# 67 (11.274930953979492, 2.4060044288635254, 8, '[CLS] when you world title , you bout . [SEP]')
# [10, 11]
# new person man ' human - young little kid child
# world
# traveler , over tour order away is view apart change
# war
# [13]
# fight think talk run sleep wait listen surrender forget kill
# beginning
# [10, 11]
# - new ' ##y little young good . go real
# world
# traveler leader traveller away champion citizen ##ly over , travel
# war
# [13]
# think sleep talk eat listen read relax work write wait
# beginning
# 68 (5.680227279663086, 1.3708100318908691, 20, '[CLS] one of the things you do when you a world war is beginning . [SEP]')
# [7]
# park play walk drive run playground go kill parks live
# center
# [3, 4]
# together out up right here forward in there back down
# park
# can say go gotta could should wanna first play hit
# city
# [7]
# die run know fight live sleep think kill listen change
# center
# [3, 4]
# hungry tired it alone there angry up ready happy out
# park
# can say go gotta could first hit should wanna play
# city
# 69 (9.226348876953125, 2.319575786590576, 7, '[CLS] when you city park , you center . [SEP]')
# [7]
# grow change breathe move stretch run die age smile jump
# shape
# [3, 4]
# light out up together here down there in around awake
# size
# change have see get want need lose take measure add
# body
# [7]
# die run know fight live sleep think kill listen change
# shape
# [3, 4]
# hungry tired it alone there angry up ready happy out
# size
# see get have want need got lose change saw know
# body
# 70 (6.527195453643799, 2.3104445934295654, 8, '[CLS] when you body size , you shape . [SEP]')
# [8, 9]
# performance one song person life play dance sound act thing
# show
# good live great stage special no big real talent little
# television
# [4]
# person show guy movie man girl kid star woman tv
# performance
# [8, 9]
# man one boy girl woman is person you thing too
# show
# good no great light big better little live fine real
# television
# [4]
# man boy girl woman child fool kid king human born
# performance
# 71 (5.91774320602417, 3.100998878479004, 11, '[CLS] when you a performance , you a television show . [SEP]')
# [7]
# care know heal protect remember learn do rest win succeed
# son
# [3, 4]
# are come get go were see die say be hear
# take
# me it her him them you off that us mine
# care
# [7]
# die run know fight live sleep think kill listen change
# son
# [3, 4]
# were are get see want need got feel saw have
# take
# it them something life blood one control someone her anything
# care
# 72 (10.298332214355469, 0.5436463356018066, 18, '[CLS] when you take care , you son . [SEP]')
# [6, 7, 8]
# to be the not become you a get your ,
# hydro
# ##lysis ##power ##pathy ##carbon ##phobia ##phobic ##thermal ##phones ##meter ##therapy
# ##xide
# use add see get need say have make form are
# calcium
# [3]
# boil water drink do heat breathe die dry freeze can
# solution
# [6, 7, 8]
# not to a the be only never always become no
# hydro
# ##power ##plane ##phobia ##phobic ##pathy ##planes ##foil ##carbon ##phones ##ids
# ##xide
# see get need have use add say find make hit
# calcium
# [3]
# die do fall can sleep run live died leave come
# solution
# 73 (9.666327476501465, 4.45857048034668, 9, '[CLS] when you solution , you calcium hydro ##xide . [SEP]')
# [9]
# telephone newspaper government operator bank company telegraph radio press city
# customer
# [4, 5]
# customer man owner person sell is customers come comes pay
# company
# insurance record holding other service parent phone big power best
# telephone
# [9]
# best man better same first king greatest last leader fool
# customer
# [4, 5]
# man sun world lord one heart boy wind king day
# telephone
# calls call rang number rings ring ##s numbers line operator
# company
# 74 (4.895738124847412, 3.361053705215454, 7, '[CLS] when you the telephone company , you the customer . [SEP]')
# [6, 7]
# kill attack are get destroy become fight do take burn
# police
# them it us me him yourself yourselves people themselves you
# station
# [3]
# come arrive leave go call run do land die work
# attack
# [6, 7]
# are were feel do go can get would will become
# police
# them yourself me it themselves people us him you yourselves
# station
# [3]
# die do sleep can run fall live fight want come
# attack
# 75 (8.927568435668945, 0.3457820415496826, 8, '[CLS] when you attack , you police station . [SEP]')
# [6, 7]
# grow are become do can eat burn breathe get make
# water
